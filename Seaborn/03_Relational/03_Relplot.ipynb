# %% [raw]
# seaborn.relplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("../Data/Train-Set.csv").sample(100)
df.head()
# Out:
#      ProductID  Weight FatContent  ProductVisibility            ProductType  \
# 6238     DRM37     NaN         LF           0.168780            Soft Drinks
# 591      FDG14   9.000    Regular           0.050786                 Canned
# 4567     NCL31     NaN    Low Fat           0.210596                 Others
# 2937     FDV44   8.365    Regular           0.039811  Fruits and Vegetables
# 6922     DRN35   8.010    Low Fat           0.070189            Hard Drinks
#
#            MRP OutletID  EstablishmentYear OutletSize LocationType  \
# 6238  197.8768   OUT019               1985      Small       Tier 1
# 591   152.2024   OUT017               2007        NaN       Tier 2
# 4567  144.7470   OUT019               1985      Small       Tier 1
# 2937  191.3188   OUT013               1987       High       Tier 3
# 6922   37.9532   OUT013               1987       High       Tier 3
#
#              OutletType  OutletSales
# 6238      Grocery Store     197.0768
# 591   Supermarket Type1    3643.2576
# 4567      Grocery Store     143.1470
# 2937  Supermarket Type1    2285.0256
# 6922  Supermarket Type1     826.9236

# %%
sns.relplot(data=df,x="EstablishmentYear",y="OutletSales",hue = "OutletSize",col="ProductType",col_wrap=4,s=300)
